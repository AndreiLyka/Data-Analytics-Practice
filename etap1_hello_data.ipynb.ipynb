# %%
import pandas as pd

# %%
data = {
    'name': ['Алекс', 'Мария', 'Иван'],
    'age': [25, 30, 28],
    'city': ['Москва', 'СПб', 'Казань']
}
df = pd.DataFrame(data)
print(df)
# Out:
#     name  age    city
# 0  Алекс   25  Москва
# 1  Мария   30     СПб
# 2   Иван   28  Казань

# %%
df.age.mean()
# Out:
# np.float64(27.666666666666668)
